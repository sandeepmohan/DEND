# %%
# %load_ext sql

# %%
# %sql postgresql://student:student@127.0.0.1/sparkifydb
# Out:
# 'Connected: student@sparkifydb'

# %%
# %sql SELECT * FROM songplay LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 91, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '829                                                                                                 ', 'Dallas-Fort Worth-Arlington, TX', 'Mozilla/5.0 (compatible; MSIE 10.0; Windows NT 6.2; WOW64; Trident/6.0)'),
#  (datetime.datetime(2018, 11, 11, 2, 33, 56, 796000), 69, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '455                                                                                                 ', 'Philadelphia-Camden-Wilmington, PA-NJ-DE-MD', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 23, 0, 7, 25, 796000), 66, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '815                                                                                                 ', 'Harrisburg-Carlisle, PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 24, 0, 45, 0, 796000), 26, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '873                                                                                                 ', 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 25, 1, 39, 14, 796000), 76, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '846                                                                                                 ', 'Seattle-Tacoma-Bellevue, WA', '"Mozilla/5.0 (iPhone; CPU iPhone OS 7_1_2 like Mac OS X) AppleWebKit/537.51.2 (KHTML, like Gecko) Version/7.0 Mobile/11D257 Safari/9537.53"'),
#  (datetime.datetime(2018, 11, 20, 0, 0, 42, 796000), 25, 'paid      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '594                                                                                                 ', 'Marinette, WI-MI', '"Mozilla/5.0 (Windows NT 6.3; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.143 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 15, 0, 30, 26, 796000), 26, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '583                                                                                                 ', 'San Jose-Sunnyvale-Santa Clara, CA', '"Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Ubuntu Chromium/36.0.1985.125 Chrome/36.0.1985.125 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 1, 21, 1, 46, 796000), 8, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '139                                                                                                 ', 'Phoenix-Mesa-Scottsdale, AZ', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/35.0.1916.153 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 3, 1, 5, 50, 796000), 53, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '52                                                                                                  ', 'Klamath Falls, OR', '"Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/37.0.2062.103 Safari/537.36"'),
#  (datetime.datetime(2018, 11, 13, 0, 40, 37, 796000), 66, 'free      ', 'NaN                                                                                                 ', 'NaN                                                                                                 ', '514                                                                                                 ', 'Harrisburg-Carlisle, PA', '"Mozilla/5.0 (Macintosh; Intel Mac OS X 10_9_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1985.125 Safari/537.36"')]

# %%
# %sql SELECT * FROM users LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(1, '91', 'Jayden', 'Bell', 'M', 'free'),
#  (2, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (3, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (4, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (5, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (6, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (7, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (8, '73', 'Jacob', 'Klein', 'M', 'paid'),
#  (9, '4', 'Alivia', 'Terrell', 'F', 'free'),
#  (10, '73', 'Jacob', 'Klein', 'M', 'paid')]

# %%
# %sql SELECT * FROM songs LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(1, 'SOMZWCG12A8C13C480', "I Didn't Mean To", 'ARD7TVE1187B99BFB1', 0, 218.93179),
#  (2, 'SOUDSGM12AC9618304', 'Insatiable (Instrumental Version)', 'ARNTLGG11E2835DDB9', 0, 266.39628),
#  (3, 'SOIAZJW12AB01853F1', 'Pink World', 'AR8ZCNI1187B9A069B', 1984, 269.81832),
#  (4, 'SOHKNRJ12A6701D1F8', 'Drop of Rain', 'AR10USD1187B99F3F1', 0, 189.57016),
#  (5, 'SOCIWDW12A8C13D406', 'Soul Deep', 'ARMJAGH1187FB546F3', 1969, 148.03546),
#  (6, 'SOYMRWW12A6D4FAB14', 'The Moon And I (Ordinary Day Album Version)', 'ARKFYS91187B98E58F', 0, 267.7024),
#  (7, 'SOMJBYD12A6D4F8557', 'Keepin It Real (Skit)', 'ARD0S291187B9B7BF5', 0, 114.78159),
#  (8, 'SOQHXMF12AB0182363', 'Young Boy Blues', 'ARGSJW91187B9B1D6B', 0, 218.77506),
#  (9, 'SONHOTT12A8C13493C', 'Something Girls', 'AR7G5I41187FB4CE6C', 1982, 233.40363),
#  (10, 'SOFSOCN12A8C143F5D', 'Face the Ashes', 'ARXR32B1187FB57099', 2007, 209.60608)]

# %%
# %sql SELECT * FROM artists LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(1, 'ARD7TVE1187B99BFB1', 'Casual', 'California - LA', nan, nan),
#  (2, 'ARNTLGG11E2835DDB9', 'Clp', '', nan, nan),
#  (3, 'AR8ZCNI1187B9A069B', 'Planet P Project', '', nan, nan),
#  (4, 'AR10USD1187B99F3F1', 'Tweeterfriendly Music', 'Burlington, Ontario, Canada', nan, nan),
#  (5, 'ARMJAGH1187FB546F3', 'The Box Tops', 'Memphis, TN', 35.1497, -90.0489),
#  (6, 'ARKFYS91187B98E58F', 'Jeff And Sheri Easter', '', nan, nan),
#  (7, 'ARD0S291187B9B7BF5', 'Rated R', 'Ohio', nan, nan),
#  (8, 'ARGSJW91187B9B1D6B', 'JennyAnyKind', 'North Carolina', 35.2196, -80.0195),
#  (9, 'AR7G5I41187FB4CE6C', 'Adam Ant', 'London, England', nan, nan),
#  (10, 'ARXR32B1187FB57099', 'Gob', '', nan, nan)]

# %%
# %sql SELECT * FROM time LIMIT 10;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 10 rows affected.
# [(1, datetime.datetime(2018, 11, 30, 0, 22, 7, 796000), 0, 30, 48, 11, 2018, 4),
#  (2, datetime.datetime(2018, 11, 30, 1, 8, 41, 796000), 1, 30, 48, 11, 2018, 4),
#  (3, datetime.datetime(2018, 11, 30, 1, 12, 48, 796000), 1, 30, 48, 11, 2018, 4),
#  (4, datetime.datetime(2018, 11, 30, 1, 17, 5, 796000), 1, 30, 48, 11, 2018, 4),
#  (5, datetime.datetime(2018, 11, 30, 1, 20, 56, 796000), 1, 30, 48, 11, 2018, 4),
#  (6, datetime.datetime(2018, 11, 30, 1, 24, 32, 796000), 1, 30, 48, 11, 2018, 4),
#  (7, datetime.datetime(2018, 11, 30, 1, 28, 19, 796000), 1, 30, 48, 11, 2018, 4),
#  (8, datetime.datetime(2018, 11, 30, 1, 32, 0, 796000), 1, 30, 48, 11, 2018, 4),
#  (9, datetime.datetime(2018, 11, 30, 1, 38, 17, 796000), 1, 30, 48, 11, 2018, 4),
#  (10, datetime.datetime(2018, 11, 30, 1, 39, 53, 796000), 1, 30, 48, 11, 2018, 4)]

# %%
# %%sql
# SELECT DISTINCT s.title song, a.name artist, s.duration, s.song_id, a.artist_id
# FROM songs s, artists a
# WHERE s.artist_id = a.artist_id
# LIMIT 15;
# Out:
#  * postgresql://student:***@127.0.0.1/sparkifydb
# 15 rows affected.
# [('Young Boy Blues', 'JennyAnyKind', 218.77506, 'SOQHXMF12AB0182363', 'ARGSJW91187B9B1D6B'),
#  ('Setting Fire to Sleeping Giants', 'The Dillinger Escape Plan', 207.77751, 'SOBBUGU12A8C13E95D', 'ARMAC4T1187FB3FA4C'),
#  ('Laws Patrolling (Album Version)', "Mike Jones (Featuring CJ_ Mello & Lil' Bran)", 173.66159, 'SOOLYAZ12A6701F4A6', 'AREBBGV1187FB523D2'),
#  ('Amor De Cabaret', 'Sonora Santanera', 177.47546, 'SOXVLOJ12AB0189215', 'ARKRRTF1187B9984DA'),
#  ('Harajuku Girls', 'Gwen Stefani', 290.55955, 'SORRZGD12A6310DBC3', 'ARVBRGZ1187FB4675A'),
#  ('Keepin It Real (Skit)', 'Rated R', 114.78159, 'SOMJBYD12A6D4F8557', 'ARD0S291187B9B7BF5'),
#  ('It Wont Be Christmas', 'David Martin', 241.47546, 'SOTTDKS12AB018D69B', 'ARMBR4Y1187B9990EB'),
#  ('Knocked Out Of The Park', 'John Davis', 183.17016, 'SOMVWWT12A58A7AE05', 'ARQ9BO41187FB5CF1F'),
#  ('Native Soul', 'Danilo Perez', 197.19791, 'SONSKXP12A8C13A2C9', 'AR0IAWL1187B9A96D0'),
#  ('Ten Tonne', 'Chase & Status', 337.68444, 'SOGVQGJ12AB017F169', 'AR62SOJ1187FB47BB5'),
#  ('Insatiable (Instrumental Version)', 'Clp', 266.39628, 'SOUDSGM12AC9618304', 'ARNTLGG11E2835DDB9'),
#  ('Der Kleine Dompfaff', 'Line Renaud', 152.92036, 'SOUPIRU12A6D4FA1E1', 'ARJIE2Y1187B994AB7'),
#  ('Erica (2005 Digital Remaster)', 'Eddie Calvert', 138.63138, 'SOBBXLX12A58A79DDA', 'AREDBBQ1187B98AFF5'),
#  ('Clementina Santafè', 'Gloriana', 153.33832, 'SOQOTLQ12AB01868D0', 'ARGCY1Y1187B9A4FA5'),
#  ('The Moon And I (Ordinary Day Album Version)', 'Jeff And Sheri Easter', 267.7024, 'SOYMRWW12A6D4FAB14', 'ARKFYS91187B98E58F')]

# %%
combined_df = pd.merge(song_match_df, next_song_df,  how='right', left_on=['artist','song'], right_on = ['artist','song'])
songplay_df = combined_df[['ts','userId','level', 'song_id', 'artist_id', 'sessionId','location','userAgent']]

# %% [markdown]
# ## REMEMBER: Restart this notebook to close connection to `sparkifydb`
# Each time you run the cells above, remember to restart this notebook to close the connection to your database. Otherwise, you won't be able to run your code in `create_tables.py`, `etl.py`, or `etl.ipynb` files since you can't make multiple connections to the same database (in this case, sparkifydb).
